# %% [markdown]
# <a href="https://colab.research.google.com/github/itsarbababdurrab/Campus-Security-AI/blob/main/016_CampusX_KNN_Imputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/CampusX Tutorials/titanic.csv", usecols=["Age","Pclass", "Fare", "Survived"])

# %%
dataset.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
dataset.isnull().mean()
# Out:
# Survived    0.000000
# Pclass      0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(dataset.drop(columns=["Survived"]), dataset["Survived"], test_size=0.2, random_state=42)

# %%
knn = KNNImputer(n_neighbors=2)
x_train_trf = knn.fit_transform(x_train)
x_test_trf = knn.transform(x_test)

# %%
pd.DataFrame(x_train_trf, columns=x_train.columns)
# Out:
#      Pclass   Age      Fare
# 0       1.0  45.5   28.5000
# 1       2.0  23.0   13.0000
# 2       3.0  32.0    7.9250
# 3       3.0  26.0    7.8542
# 4       3.0   6.0   31.2750
# ..      ...   ...       ...
# 707     3.0  21.0    7.6500
# 708     1.0  39.5   31.0000
# 709     3.0  41.0   14.1083
# 710     1.0  14.0  120.0000
# 711     1.0  21.0   77.2875
#
# [712 rows x 3 columns]

# %%
lr = LogisticRegression()
lr.fit(x_train_trf, y_train)
y_pred = lr.predict(x_test_trf)
accuracy_score(y_test, y_pred)
# Out:
# 0.7430167597765364
